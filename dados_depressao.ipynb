# %%
import pandas as pd

# %% [markdown]
# # Tab 3.44
# ## Sheet 1 - Proporção de diagnosticos de depressão de acordo com o sexo

# %%
tab3_44_sexo = pd.read_excel('dados/3.44.xls')

# %% [markdown]
# ### Removendo colunas desnecessárias

# %%
tab3_44_sexo.dropna(inplace=True)
tab3_44_sexo.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 5','Unnamed: 6','Unnamed: 8','Unnamed: 9'],inplace=True)

# %% [markdown]
# ### Renomaendo colunas

# %%
colunas = ['Estado','Diagnostico Depressão Total', 'Diagnostico Depressão Masculino', 'Diagnostico Depressão Feminino']
tab3_44_sexo.columns = colunas

# %%
tab3_44_sexo.head(5)
# Out:
#       Estado Diagnostico Depressão Total Diagnostico Depressão Masculino  \
# 8     Brasil                        10.2                             5.1
# 9     Urbana                        10.7                             5.4
# 10    Rural                          7.6                             3.5
# 11     Norte                           5                             2.9
# 12  Rondônia                           9                             5.1
#
#    Diagnostico Depressão Feminino
# 8                            14.7
# 9                            15.1
# 10                           12.3
# 11                              7
# 12                           12.8

# %% [markdown]
# ### Removendo linhas com dados totais do brasil e de regiões, mantando apenas as colunas de cada estado

# %%
tab3_44_sexo.drop(tab3_44_sexo.iloc[0:3].index,inplace=True)
selecao = (tab3_44_sexo['Estado'] == 'Norte') | (tab3_44_sexo['Estado'] == 'Nordeste') | (tab3_44_sexo['Estado'] == 'Sudeste') | (tab3_44_sexo['Estado'] == 'Centro-Oeste') | (tab3_44_sexo['Estado'] == 'Sul')
tab3_44_sexo.drop(tab3_44_sexo[selecao].index,inplace=True)

# %%
tab3_44_sexo.reset_index(drop=True,inplace=True)

# %%
tab3_44_sexo.loc[0:7, 'Região'] = 'Norte'
tab3_44_sexo.loc[7:16, 'Região'] = 'Nordeste'
tab3_44_sexo.loc[16:20, 'Região'] = 'Sudeste'
tab3_44_sexo.loc[20:23, 'Região'] = 'Sul'
tab3_44_sexo.loc[23:, 'Região'] = 'Centro-Oeste'

# %% [markdown]
# ### Corrigindo tipo de colunas numericas

# %%
tab3_44_sexo.dtypes
# Out:
# Estado                             object
# Diagnostico Depressão Total        object
# Diagnostico Depressão Masculino    object
# Diagnostico Depressão Feminino     object
# Região                             object
# dtype: object

# %%
colunas_numericas = ['Diagnostico Depressão Total', 'Diagnostico Depressão Masculino', 'Diagnostico Depressão Feminino']
tab3_44_sexo[colunas_numericas] = tab3_44_sexo[colunas_numericas].apply(pd.to_numeric, errors='coerce')
tab3_44_sexo.head()
# Out:
#       Estado  Diagnostico Depressão Total  Diagnostico Depressão Masculino  \
# 0   Amazonas                          4.2                              2.9
# 1    Roraima                          5.1                              2.8
# 2       Pará                          4.1                              2.5
# 3      Amapá                          4.5                              2.0
# 4  Tocantins                          6.6                              2.7
#
#    Diagnostico Depressão Feminino Região
# 0                             5.4  Norte
# 1                             7.3  Norte
# 2                             5.6  Norte
# 3                             6.9  Norte
# 4                            10.4  Norte

# %% [markdown]
# ## Sheet 2 - Proporção de diagnosticos de depressão por grupo de idade

# %%
tab3_44_idade = pd.read_excel('dados/3.44.xls',sheet_name='grupos_de_idade')

# %%
tab3_44_idade.dropna(inplace=True)
tab3_44_idade
# Out:
#    Tabela 3.44.2.1 - Proporção de pessoas de 18 anos ou mais de idade que referem diagnóstico de depressão por profissional de saúde mental, por grupos de idade, com indicação do intervalo de confiança de 95%, segundo as Grandes Regiões, as Unidades da Federação e a situação do domicílio - 2019  \
# 8                                              Brasil
# 9                                              Urbana
# 10                                             Rural
# 11                                              Norte
# 12                                           Rondônia
# 13                                               Acre
# 14                                           Amazonas
# 15                                            Roraima
# 16                                               Pará
# 17                                              Amapá
# 18                                          Tocantins
# 19                                           Nordeste
# 20                                           Maranhão
# 21                                              Piauí
# 22                                              Ceará
# 23                                Rio Grande do Norte
# 24                                            Paraíba
# 25                                         Pernambuco
# 26                                            Alagoas
# 27                                            Sergipe
# 28                                              Bahia
# 29                                            Sudeste
# 30                                       Minas Gerais
# 31                                     Espírito Santo
# 32                                     Rio de Janeiro
# 33                                          São Paulo
# 34                                                Sul
# 35                                             Paraná
# 36                                     Santa Catarina
# 37                                  Rio Grande do Sul
# 38                                       Centro-Oeste
# 39                                 Mato Grosso do Sul
# 40                                        Mato Grosso
# 41                                              Goiás
# 42                                   Distrito Federal
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 8        10.2        9.9       10.6        5.9        5.2        6.6
# 9        10.7       10.2       11.1        6.2        5.4        7.1
# 10        7.6          7        8.3        3.8        2.6        4.9
# 11          5        4.4        5.6        3.2        2.5        3.9
# 12          9        7.3       10.7        7.2          4       10.4
# 13          6        4.8        7.2        2.7        1.4          4
# 14        4.2        3.2        5.2          4          2        6.1
# 15        5.1        3.9        6.3        4.8        1.9        7.6
# 16        4.1          3        5.2        1.7        0.8        2.6
# 17        4.5        2.4        6.7        4.8        2.1        7.5
# 18        6.6        5.3          8        4.1        1.6        6.6
# 19        6.9        6.5        7.3        3.5        2.8        4.1
# 20        5.4        4.7        6.2        3.1        1.6        4.6
# 21        6.9        5.6        8.2        5.5        2.5        8.5
# 22        8.1          7        9.2        4.5        2.4        6.7
# 23        8.5        7.2        9.8        4.1        2.2          6
# 24        7.6        6.3        8.8        3.3        1.5        5.2
# 25        6.8        5.7        7.8        3.6        1.7        5.4
# 26        6.2          5        7.4        2.6        0.8        4.4
# 27        8.5        7.4        9.7          4        2.1        5.9
# 28        6.3        5.3        7.3        2.4        0.9        3.9
# 29       11.5       10.8       12.2        7.3        5.7        8.9
# 30       13.7       12.1       15.2        7.1        3.6       10.7
# 31       11.3        9.8       12.8        6.3        4.2        8.5
# 32        8.1        7.1          9          5        3.2        6.9
# 33       11.8       10.6       12.9        8.3        5.8       10.9
# 34       15.2       14.2       16.2        8.6          7       10.2
# 35       13.9       12.2       15.6        8.2        5.8       10.7
# 36       13.1       11.8       14.5        7.4        4.8         10
# 37       17.9       16.2       19.6        9.9        6.7       13.2
# 38       10.4        9.5       11.3        5.9        4.4        7.5
# 39       10.1        8.8       11.3        6.5        4.3        8.7
# 40        8.2        6.8        9.5        3.9        1.5        6.4
# 41         12       10.3       13.8          6        2.9          9
# 42        9.4        7.8         11        7.6        4.5       10.8
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 8        11.3       10.8       11.9
# 9        11.7       11.1       12.3
# 10        8.8        7.8        9.7
# 11        5.6        4.7        6.6
# 12        9.9        7.3       12.6
# 13        7.6        5.8        9.4
# 14          4        2.9        5.1
# 15        5.2        3.8        6.6
# 16        5.1        3.2          7
# 17        3.7          2        5.4
# 18        7.4        5.6        9.1
# 19        7.9        7.3        8.5
# 20        6.7        5.7        7.8
# 21        7.6        5.7        9.5
# 22        8.5        7.2        9.9
# 23       10.7        8.5       12.9
# 24        8.9        7.1       10.7
# 25        7.5          6        8.9
# 26        7.8          6        9.6
# 27       10.1        8.3       11.8
# 28        7.2        5.7        8.7
# 29       12.6       11.6       13.7
# 30       15.8       13.7       17.9
# 31       13.4         11       15.7
# 32        8.9        7.5       10.2
# 33       12.5       10.9       14.1
# 34       16.2       14.9       17.5
# 35       14.8       12.5         17
# 36       13.6       11.8       15.4
# 37       19.3         17       21.6
# 38       12.1       10.8       13.3
# 39       11.5        9.8       13.2
# 40        9.6        7.8       11.3
# 41       14.2       11.7       16.7
# 42       10.4        8.4       12.5
#
#    Tabela 3.44.2.1 - Proporção de pessoas de 18 anos ou mais de idade que referem diagnóstico de depressão por profissional de saúde mental, por grupos de idade, com indicação do intervalo de confiança de 95%, segundo as Grandes Regiões, as Unidades da Federação e a situação do domicílio - 2019.1  \
# 8                                              Brasil
# 9                                              Urbana
# 10                                             Rural
# 11                                              Norte
# 12                                           Rondônia
# 13                                               Acre
# 14                                           Amazonas
# 15                                            Roraima
# 16                                               Pará
# 17                                              Amapá
# 18                                          Tocantins
# 19                                           Nordeste
# 20                                           Maranhão
# 21                                              Piauí
# 22                                              Ceará
# 23                                Rio Grande do Norte
# 24                                            Paraíba
# 25                                         Pernambuco
# 26                                            Alagoas
# 27                                            Sergipe
# 28                                              Bahia
# 29                                            Sudeste
# 30                                       Minas Gerais
# 31                                     Espírito Santo
# 32                                     Rio de Janeiro
# 33                                          São Paulo
# 34                                                Sul
# 35                                             Paraná
# 36                                     Santa Catarina
# 37                                  Rio Grande do Sul
# 38                                       Centro-Oeste
# 39                                 Mato Grosso do Sul
# 40                                        Mato Grosso
# 41                                              Goiás
# 42                                   Distrito Federal
#
#    Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 8         13.2        11.8        14.7        11.8        10.6        12.9
# 9         13.9        12.3        15.5        12.1        10.8        13.4
# 10           9         6.7        11.4         9.7         7.2        12.2
# 11         5.7         3.4         7.9         6.3         4.5         8.1
# 12         6.9         2.1        11.7        10.9         5.6        16.2
# 13         5.9         2.4         9.5         9.7           4        15.4
# 14         5.8         1.8         9.7         6.6         2.9        10.2
# 15         3.4           0         7.2         7.1         2.6        11.7
# 16         5.1           1         9.2           4         1.3         6.7
# 17         4.3           0           9        10.7           0        22.4
# 18         7.7         1.5          14         9.3         4.4        14.3
# 19         9.1         7.2        10.9         8.9         7.2        10.6
# 20         3.4         1.2         5.6         6.8         3.9         9.7
# 21         7.4         3.4        11.5         7.1         3.9        10.2
# 22          13         7.4        18.6         9.8         6.7        12.8
# 23         9.9         5.5        14.4           7           4        10.1
# 24          10         4.9        15.1         9.5         5.8        13.1
# 25         9.9         5.5        14.3         8.6         5.8        11.4
# 26         5.5         2.2         8.7         6.9         3.8         9.9
# 27         9.6         4.1        15.1        10.5         5.9        15.1
# 28         8.9         4.3        13.5        10.2         4.5        15.9
# 29        14.4        11.8          17        11.8         9.7        13.9
# 30        13.8         9.2        18.3        16.4        11.6        21.1
# 31        15.9        10.2        21.5         9.5         5.9        13.2
# 32        10.9         7.2        14.6         8.5           6          11
# 33        16.4        11.9        20.8        11.2           8        14.5
# 34        19.3        15.9        22.7        18.9        16.1        21.7
# 35        18.8        12.6          25        17.5        12.3        22.7
# 36        16.8        11.9        21.6        19.6        14.8        24.4
# 37        21.7        15.8        27.5        19.5        15.1        23.9
# 38        12.1         8.4        15.8        10.4         7.5        13.3
# 39           8         4.4        11.7        10.6           7        14.1
# 40        14.1         6.2          22        10.6         5.2        16.1
# 41          14           7          21        11.9         6.4        17.5
# 42         9.6         4.7        14.5         5.8         2.5         9.2
#
#    Unnamed: 17 Unnamed: 18 Unnamed: 19
# 8         10.2         8.8        11.5
# 9         10.8         9.3        12.4
# 10         6.6         4.7         8.6
# 11         5.2         2.8         7.6
# 12         6.6           1        12.3
# 13           2           0         4.2
# 14         2.2           0         4.7
# 15         4.1           0         9.7
# 16         6.4         1.9        10.8
# 17         5.5         0.7        10.4
# 18           5         0.5         9.6
# 19         6.3         4.9         7.7
# 20         3.6         0.7         6.5
# 21         4.5         1.4         7.5
# 22        10.7         5.9        15.5
# 23         6.5         2.8        10.3
# 24         6.4         2.9         9.8
# 25         6.2         3.2         9.2
# 26         6.1         1.8        10.4
# 27         8.5         3.5        13.6
# 28         4.9         2.1         7.6
# 29        11.1         8.6        13.6
# 30        12.7         8.3        17.1
# 31         6.4         2.8         9.9
# 32         6.7         3.7         9.7
# 33        12.6         8.2          17
# 34        16.3        12.6          20
# 35        14.8         8.3        21.3
# 36        11.8         7.1        16.5
# 37        19.8        13.7        25.8
# 38        11.2         7.8        14.6
# 39        12.4         5.8        19.1
# 40         4.5           0           9
# 41        13.5         7.5        19.4
# 42        13.1         4.4        21.8
